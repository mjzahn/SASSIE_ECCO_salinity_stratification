# %% [markdown]
# # Mackenzie runoff climatology

# %%
## import required packages
import numpy as np
import pandas as pd
import sys
import xarray as xr
import matplotlib.pyplot as plt
import s3fs
import cmocean
import gsw
import matplotlib.dates as mdates
import time
import cartopy.crs as ccrs
import warnings
warnings.filterwarnings("ignore", module='distributed')

# %%
# initialize s3 filesystem
s3_options = dict(anon=False)

# %%
# open geometry file for HH field
HH_grid = xr.open_dataset("~/efs-mount-point/mzahn/sassie/HH/GRID/GRID_GEOMETRY_SASSIE_HH_V1R1_NATIVE_LLC1080.nc")

# %%
# function to open zarr store with a provided s3 bucket path
def open_zarr_store(s3_path, s3_options):
    # initalize s3 file system
    s3 = s3fs.S3FileSystem(**s3_options)

    # define location of zarr store and open
    store = s3fs.S3Map(root=s3_path, s3=s3, check=False)
    zarr_store = xr.open_zarr(store)
    
    return zarr_store

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:35059")
client
# Out:
# <Client: 'tcp://127.0.0.1:35059' processes=8 threads=32, memory=123.95 GiB>

# %% [markdown]
# ### Open daily mean ZARR datasets

# %%
# open runoff zarr store - [m s-1]
runoff_da = open_zarr_store('s3://ecco-processed-data/SASSIE/N1/HH/ZARR/EXFroff_AVG_DAILY.ZARR/', s3_options)

# %%
# carve out beaufort region
runoff_da_beaufort = runoff_da.EXFroff.isel(i=slice(450,750),j=slice(110,390))

HH_grid_land = HH_grid.maskC.isel(k=0).where(HH_grid.maskC.isel(k=0)==0)
HH_land_beaufort = HH_grid_land.isel(i=slice(450,750),j=slice(110,390))

# %% [markdown]
# # Plot climatology

# %%
runoff_monthly = runoff_da_beaufort.groupby('time.month').mean(dim='time')

# %%
runoff_month_clim = runoff_monthly.sum(dim=['i','j'])

# %%
runoff_month_clim.plot()
plt.grid();

# %% [markdown]
# ## Convert to cubic meters per second

# %%
beaufort_area = HH_grid.rAc.isel(i=slice(450,750),j=slice(110,390))

# %%
plt.rcParams['font.size'] = 16

(runoff_da_beaufort.sel(time='2020')*beaufort_area).sum(dim=['i','j']).plot(color='k',figsize=[10,2.5])
plt.xlim([np.datetime64('2020-01-01'),np.datetime64('2020-12-31')])
plt.xlabel("")
plt.ylim(0,3e4)

dates = pd.date_range('2020-01-01', '2020-12-01', freq='MS')
plt.xticks(ticks=dates, labels=['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])

plt.ylabel("River runoff (m$^3$s$^{-1}$)")
plt.title("Mackenzie River runoff climatology")
plt.grid();

# %% [markdown]
# ## Add observations

# %% [markdown]
# Data are downloaded from the Arctic Great Rivers Observatory here: https://arcticgreatrivers.org/discharge/
#
# Main website here: https://arcticgreatrivers.org/

# %%
# Read the Excel spreadsheet
# replace "discharge_data.xlsx" with your filename
df = pd.read_excel("~/efs-mount-point/mzahn/sassie/Mack_runoff/Mackenzie_ArcticRedRiver_Version_20250327.xlsx")

# Ensure date is datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Convert discharge to numeric (turns "NA" into NaN automatically)
df['discharge'] = pd.to_numeric(df['discharge'], errors='coerce')

# %%
# Create an xarray DataArray
discharge_da = xr.DataArray(
    df['discharge'].values,
    coords={"time": df['date'].values},
    dims=["time"],
    name="discharge"
)

# %%
# Plot using xarray’s built-in plot (matplotlib under the hood)
discharge_da.plot.line(figsize=(12, 2))

plt.title("Mackenzie River Discharge")
plt.xlabel("Date")
plt.ylabel("Discharge (m³/s)")
plt.grid(True)
plt.show()

# %%
# Resample to monthly mean
monthly_da = discharge_da.resample(time='M').mean()

# Group by year
monthly_by_year = monthly_da.groupby('time.year')

plt.figure(figsize=(8,3))

# Loop through each year and plot the monthly time series
for year, da_year in monthly_by_year:
    # Use the month number for x-axis (1-12)
    da_year_months = da_year['time.month']
    plt.plot(da_year_months, da_year.values, label=str(year))

plt.xlabel('Month')
plt.ylabel('Monthly Mean Discharge')
plt.title('Monthly Mean Discharge by Year')
plt.xticks(range(1,13))
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', ncol=1, fontsize='small')
plt.tight_layout()
plt.show()
# Out:
# /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/xarray/groupers.py:490: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   self.index_grouper = pd.Grouper(

# %%
# Calculate daily climatology (group by DOY)
obs_clim_doy = discharge_da.sel(time=slice("2014","2020")).groupby('time.dayofyear').mean('time')
# obs_clim_doy = discharge_da.groupby('time.dayofyear').mean('time')

# Create time coordinate for 2020 (DOY → actual dates)
time_coord = pd.date_range(start='2020-01-01', end='2020-12-31', freq='D')

# Assign the time coordinate
obs_clim_da = obs_clim_doy.copy()
obs_clim_da = obs_clim_da.assign_coords(dayofyear=time_coord)

# Optional: drop the old 'dayofyear' coordinate to avoid confusion
obs_clim_da = obs_clim_da.rename({'dayofyear':'time'})

# %%
# model climatology
model_clim = (runoff_da_beaufort.sel(time='2020')*beaufort_area).sum(dim=['i','j'])

# %%
plt.rcParams['font.size'] = 16

model_clim.plot(color='k',figsize=[10,2.5],label='Model')
obs_clim_da.plot(color='tab:blue',label='River Gauge')
plt.xlim([np.datetime64('2020-01-01'),np.datetime64('2020-12-31')])
plt.xlabel("")
plt.ylim(0,3e4)
plt.legend()

dates = pd.date_range('2020-01-01', '2020-12-01', freq='MS')
plt.xticks(ticks=dates, labels=['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])

plt.ylabel("River runoff (m$^3$s$^{-1}$)")
plt.title("Mackenzie River Runoff")
plt.grid();

plt.savefig('/home/jpluser/git_repos/SASSIE_ECCO_salinity_stratification/figures/mack_runoff_climatology.png',
            dpi=300, bbox_inches='tight')
