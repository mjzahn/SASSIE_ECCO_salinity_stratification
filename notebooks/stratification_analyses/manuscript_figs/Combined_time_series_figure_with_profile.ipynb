# %% [markdown]
# # Combined time series figure with vertical profile

# %%
## import required packages
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.lines import Line2D
import matplotlib.ticker as ticker
import matplotlib.gridspec as gridspec
import string
import s3fs
import gsw
import warnings
warnings.filterwarnings("ignore", module='distributed')

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:35145")
client
# Out:
# <Client: 'tcp://127.0.0.1:35145' processes=8 threads=32, memory=123.95 GiB>

# %%
# initialize s3 filesystem
s3_options = dict(anon=False)

# %%
# open geometry file for HH field
HH_grid = xr.open_dataset("~/efs-mount-point/mzahn/sassie/HH/GRID/GRID_GEOMETRY_SASSIE_HH_V1R1_NATIVE_LLC1080.nc")

# %%
# function to open zarr store with a provided s3 bucket path
def open_zarr_store(s3_path, s3_options):
    # initalize s3 file system
    s3 = s3fs.S3FileSystem(**s3_options)

    # define location of zarr store and open
    store = s3fs.S3Map(root=s3_path, s3=s3, check=False)
    zarr_store = xr.open_zarr(store)
    
    return zarr_store

# %% [markdown]
# ### Open ZARR datasets

# %%
# open SALT zarr store - [psu]
SALT_zarr_day = open_zarr_store('s3://ecco-processed-data/SASSIE/N1/HH/ZARR/SALT_AVG_DAILY.ZARR/', s3_options)

# open THETA zarr store - [degC]
THETA_zarr_day = open_zarr_store('s3://ecco-processed-data/SASSIE/N1/HH/ZARR/THETA_AVG_DAILY.ZARR/', s3_options)

# %%
# open FWC dataset
# fwc_yrs_masked = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/FWC/FWC_masked_Beaufort.ZARR')
fwc_yrs_masked = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/FWC/FWC_masked_Beaufort_final.ZARR')
# fwc_yrs_masked = fwc_yrs_masked.fwc_yrs_masked
fwc_yrs_masked = fwc_yrs_masked.fwc_masked

# %%
# open SIC dataset
sic_ds = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/SIC/SIC_masked_Beaufort.ZARR')

ice_fwc_over_3m = sic_ds.sic.where(fwc_yrs_masked>3).load()
ice_fwc_under_3m = sic_ds.sic.where(fwc_yrs_masked<3).load()

# %%
# open OHC zarr stores
ohc_mld_ds = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/OHC/OHC_MLD_Beaufort_final.ZARR')
ohc_pyc_ds = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/OHC/OHC_PYC_Beaufort_final.ZARR')

# select all cells with FWC above and below 3
ohc_fwc_over_3m =(ohc_mld_ds.ohc/1e6).where(fwc_yrs_masked>3).load() # convert J to MJ
ohc_fwc_under_3m = (ohc_mld_ds.ohc/1e6).where(fwc_yrs_masked<3).load() # convert J to MJ

ohc_pyc_fwc_over_3m = (ohc_pyc_ds.ohc_pyc/1e6).where(fwc_yrs_masked>3).load()
ohc_pyc_fwc_under_3m = (ohc_pyc_ds.ohc_pyc/1e6).where(fwc_yrs_masked<3).load()

# %%
# open MLD dataset
mld_da = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/MLD/MLD_Beaufort_final.ZARR')

# select all cells with FWC above and below 2
mld_fwc_over_3m = (mld_da.mld.where(fwc_yrs_masked>3)*-1).load()
mld_fwc_under_3m = (mld_da.mld.where(fwc_yrs_masked<3)*-1).load()

# %%
strat_da = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/STRAT/STRAT_Beaufort.ZARR')

# select all cells with FWC>2
strat_fwc_over_3m = strat_da.sigma.where(fwc_yrs_masked>3).load()
strat_fwc_under_3m = strat_da.sigma.where(fwc_yrs_masked<3).load()

# %% [markdown]
# ### Add vertical lines for where SIC>=15% and remain above it for at least 5 days

# %%
# first day when sea ice concentration (SIC) reaches or exceeds 15% and stays above that threshold for at least 5 consecutive days
years = np.arange(2014, 2021)

ice_fwc_over_3m_dates = []
ice_fwc_under_3m_dates = []

for year in years:
    # Compute mean SIC over space
    ice_over_mean = ice_fwc_over_3m.sel(time=str(year)).mean(dim=['i', 'j'], skipna=True).compute()
    ice_under_mean = ice_fwc_under_3m.sel(time=str(year)).mean(dim=['i', 'j'], skipna=True).compute()
    
    # Convert to boolean where SIC >= 15
    ice_over_bool = ice_over_mean >= 15
    ice_under_bool = ice_under_mean >= 15

    # Find the first day where there are 5+ consecutive True values
    def find_persistent_threshold(bool_array, time_array, window=5):
        bool_np = bool_array.values
        for i in range(len(bool_np) - window + 1):
            if np.all(bool_np[i:i+window]):
                return time_array[i].values
        return np.datetime64('NaT')  # If no valid period found

    over_time = ice_over_mean['time']
    under_time = ice_under_mean['time']

    ice_over_date = find_persistent_threshold(ice_over_bool, over_time)
    ice_under_date = find_persistent_threshold(ice_under_bool, under_time)

    ice_fwc_over_3m_dates.append(ice_over_date)
    ice_fwc_under_3m_dates.append(ice_under_date)

# %% [markdown]
# ## Combined plot

# %%
def compute_aligned_stats(data_over, data_under, year):
    # Select data for a specific year
    data_over_yr = data_over.sel(time=str(year))
    data_under_yr = data_under.sel(time=str(year))

    # Find the first valid sea ice day (non-NaN mean)
    mean_over = data_over_yr.mean(dim=['i', 'j'])
    first_valid_index = mean_over.notnull().argmax().compute().item()

    # Slice data from that index onward
    mean_over = mean_over.isel(time=slice(first_valid_index, None))
    mean_under = data_under_yr.mean(dim=['i', 'j']).isel(time=slice(first_valid_index, None))

    std_over = data_over_yr.isel(time=slice(first_valid_index, None)).std(dim=['i', 'j'])
    std_under = data_under_yr.isel(time=slice(first_valid_index, None)).std(dim=['i', 'j'])

    x = np.arange(len(mean_over))  # relative day index

    return x, mean_over, std_over, mean_under, std_under

def plot_variable_row(fig, axes_row, year, variable_pairs, titles, ice_fwc_over_3m_dates, ice_fwc_under_3m_dates, row_idx):
    for j, ((data_over, data_under), title) in enumerate(zip(variable_pairs, titles)):
        ax = axes_row[j]
        x, mean_over, std_over, mean_under, std_under = compute_aligned_stats(data_over, data_under, year)

        ax.plot(x, mean_over, color='tab:blue', label='FWC > 2m')
        ax.fill_between(x, mean_over - std_over, mean_over + std_over, color='tab:blue', alpha=0.3)

        ax.plot(x, mean_under, color='k', label='FWC < 2m')
        ax.fill_between(x, mean_under - std_under, mean_under + std_under, color='gray', alpha=0.2)

        ax.set_xlim([0, 60])
        ax.grid(True)

        if j == 0:
            ax.set_ylabel(f"{year}", rotation=0, labelpad=30, fontsize=16)
            ax.axvline(x=np.where(mean_over.time.values == ice_fwc_over_3m_dates[row_idx])[0][0],color='tab:blue',linestyle='dashed')
            ax.axvline(x=np.where(mean_under.time.values == ice_fwc_under_3m_dates[row_idx])[0][0],color='k',linestyle='dashed')
            
        if year == 2014:
            ax.set_title(title, fontsize=16)

# %% [markdown]
# ## Mean of all time series

# %%
# Store the normalized DataArrays
normalized_sic_list = []

# Loop over each year
for year, da_year in ice_fwc_under_3m.groupby('time.year'):
    
    # Compute days since start of that year (or since sea ice min)
    days_since_min = ((da_year.time - da_year.time.values[0]) / np.timedelta64(1, 'D')).astype(int)
    
    # Replace the time coordinate with days_since_min
    da_year = da_year.assign_coords(time=days_since_min.data)
    da_year = da_year.rename({'time': 'days_since_min'})
    
    # Add 'year' as a new dimension
    da_year = da_year.expand_dims(dim={'year': [year]})
    
    normalized_sic_list.append(da_year)

# Concatenate into a single DataArray with dims: (year, days_since_min, j, i)
sic_normalized = xr.concat(normalized_sic_list, dim='year')

# Now take spatial mean (only once!)
sic_mean_under = sic_normalized.mean(dim=['j', 'i', 'year'])  # dims: (year, days_since_min)
sic_std_under = sic_normalized.std(dim=['j', 'i', 'year'])  # dims: (year, days_since_min)

# %%
sic_normalized.count().sum().item()
# Out:
# 11206529

# %%
# Store the normalized DataArrays
normalized_sic_list = []

# Loop over each year
for year, da_year in ice_fwc_over_3m.groupby('time.year'):
    
    # Compute days since start of that year (or since sea ice min)
    days_since_min = ((da_year.time - da_year.time.values[0]) / np.timedelta64(1, 'D')).astype(int)
    
    # Replace the time coordinate with days_since_min
    da_year = da_year.assign_coords(time=days_since_min.data)
    da_year = da_year.rename({'time': 'days_since_min'})
    
    # Add 'year' as a new dimension
    da_year = da_year.expand_dims(dim={'year': [year]})
    
    normalized_sic_list.append(da_year)

# Concatenate into a single DataArray with dims: (year, days_since_min, j, i)
sic_normalized = xr.concat(normalized_sic_list, dim='year')

# Now take spatial mean (only once!)
sic_mean_over = sic_normalized.mean(dim=['j', 'i', 'year'])  # dims: (year, days_since_min)
sic_std_over = sic_normalized.std(dim=['j', 'i', 'year'])  # dims: (year, days_since_min)

# %%
sic_normalized.count().sum().item()
# Out:
# 5013277

# %% [markdown]
# ### Function to average over individual profiles across all years

# %%
def normalize_and_avg_da(da, group_dim='time.year', min_day_dim='days_since_min',
                         spatial_dims=['j', 'i'], time_dim='time'):
    """
    Normalize a DataArray by computing days since the start of each year (or group),
    then compute the mean and std over space and group (e.g., year).

    Parameters:
    -----------
    da : xarray.DataArray
        The input DataArray with dimensions including time and spatial dims.
    group_dim : str
        The time-based group dimension for separation (default: 'time.year').
    min_day_dim : str
        The name for the new time coordinate (default: 'days_since_min').
    spatial_dims : list of str
        The names of spatial dimensions to average over (default: ['j', 'i']).
    time_dim : str
        The name of the time dimension (default: 'time').

    Returns:
    --------
    da_mean : xarray.DataArray
        Mean over space and group. Dims: (days_since_min,)
    da_std : xarray.DataArray
        Std deviation over space and group. Dims: (days_since_min,)
    """
    normalized_list = []

    for group_val, da_group in da.groupby(group_dim):
        days_since = ((da_group[time_dim] - da_group[time_dim].values[0]) /
                      np.timedelta64(1, 'D')).astype(int)
        da_group = da_group.assign_coords({time_dim: days_since.data})
        da_group = da_group.rename({time_dim: min_day_dim})
        da_group = da_group.expand_dims(dim={group_dim.split('.')[-1]: [group_val]})
        normalized_list.append(da_group)

    da_normalized = xr.concat(normalized_list, dim=group_dim.split('.')[-1])
    da_mean = da_normalized.mean(dim=spatial_dims + [group_dim.split('.')[-1]])
    da_std = da_normalized.std(dim=spatial_dims + [group_dim.split('.')[-1]])

    return da_mean, da_std

# %%
# compute normalized datasets and mean/std

# SIC --------------------------
sic_mean_over, sic_std_over = normalize_and_avg_da(ice_fwc_over_3m)
sic_mean_under, sic_std_under = normalize_and_avg_da(ice_fwc_under_3m)

# OHC in surface ML ------------
ohc_mean_over, ohc_std_over = normalize_and_avg_da(ohc_fwc_over_3m)
ohc_mean_under, ohc_std_under = normalize_and_avg_da(ohc_fwc_under_3m)

# OHC in pyc layer -------------
ohc_pyc_mean_over, ohc_pyc_std_over = normalize_and_avg_da(ohc_pyc_fwc_over_3m)
ohc_pyc_mean_under, ohc_pyc_std_under = normalize_and_avg_da(ohc_pyc_fwc_under_3m)

# MLD --------------------------
mld_mean_over, mld_std_over = normalize_and_avg_da(mld_fwc_over_3m)
mld_mean_under, mld_std_under = normalize_and_avg_da(mld_fwc_under_3m)

# stratification ---------------
strat_mean_over, strat_std_over = normalize_and_avg_da(strat_fwc_over_3m)
strat_mean_under, strat_std_under = normalize_and_avg_da(strat_fwc_under_3m)

# %% [markdown]
# ### Look at time series of mean salinity in upper 10 m and mean surface salinity

# %%
grid_beaufort = HH_grid.isel(i=slice(510,750),j=slice(110,390))

# %%
salt_beaufort = SALT_zarr_day.SALT.isel(i=slice(510,750),j=slice(110,390)).sel(time=fwc_yrs_masked.time.values)
salt_beaufort = salt_beaufort.where(grid_beaufort.mask_basin)

# %%
salt_beaufort.isel(time=0,k=0).plot();

# %%
salt_10m_over_3m = salt_beaufort.isel(k=slice(0,7)).mean(dim='k').where(fwc_yrs_masked>3)
salt_10m_under_3m = salt_beaufort.isel(k=slice(0,7)).mean(dim='k').where(fwc_yrs_masked<3)

sss_over_3m = salt_beaufort.isel(k=0).where(fwc_yrs_masked>3).load()
sss_under_3m = salt_beaufort.isel(k=0).where(fwc_yrs_masked<3).load()

# %%
# mean salinity in upper 10 m --------------------------
salt_10m_mean_over, salt_10m_std_over = normalize_and_avg_da(salt_10m_over_3m)
salt_10m_mean_under, salt_10m_std_under = normalize_and_avg_da(salt_10m_under_3m)

# mean surface salinity ---------------
sss_mean_over, sss_std_over = normalize_and_avg_da(sss_over_3m)
sss_mean_under, sss_std_under = normalize_and_avg_da(sss_under_3m)

# %%
def plot_var_mean(ax, var_mean_under, var_std_under, var_mean_over, var_std_over, upper_xy_limits=[80 ,100], title='SIC', ylabel=''):
    # Plot the variable mean + std shading for over and under FWC=2
    var_mean_over.plot(ax=ax, color='tab:blue', label='Plume')
    ax.fill_between(
        var_mean_over.days_since_min,
        var_mean_over - var_std_over,
        var_mean_over + var_std_over,
        color='tab:blue', alpha=0.2)

    var_mean_under.plot(ax=ax, color='k', label='Adjacent')
    ax.fill_between(
        var_mean_under.days_since_min,
        var_mean_under - var_std_under,
        var_mean_under + var_std_under,
        color='gray', alpha=0.2)

    ax.set_xlim(20, upper_xy_limits[0])
    ax.set_ylim(20, upper_xy_limits[1])
    ax.set_xlabel("")
    ax.set_title(title,size=15)
    ax.set_ylabel(ylabel)

# %%
plt.rcParams['font.size'] = 14

fig, (ax1,ax2) = plt.subplots(1,2,figsize=[10,3])

plot_var_mean(ax1, salt_10m_mean_under, salt_10m_std_under, salt_10m_mean_over, salt_10m_std_over,
              upper_xy_limits=[80, 35], title='Mean Salinity in upper 10 m', ylabel='Salinity (g/kg)')
plot_var_mean(ax2, sss_mean_under, sss_std_under, sss_mean_over, sss_std_over,
              upper_xy_limits=[80, 35], title='Mean SSS', ylabel=r'SSS (g/kg)')

# ax1.text(0, 1.15, '(a)', transform=ax1.transAxes, fontsize=15, va='top', ha='left')
# ax2.text(0, 1.15, '(b)', transform=ax2.transAxes, fontsize=15, va='top', ha='left')

ax1.legend()

# Shared X-axis label
fig.text(0.5, -0.02, "Days Following Sea Ice Minimum", ha='center', size=13);

# %%
print(f'adjacent max: {sss_mean_under.max().values}')
print(f'adjacent min: {sss_mean_under.min().values}')
print(f'plume max: {sss_mean_over.max().values}')
print(f'plume min: {sss_mean_over.min().values}')
# Out:
# adjacent max: 30.342150584856938
# adjacent min: 29.26452038533775
# plume max: 25.150283561717444
# plume min: 23.300949634565956

# %% [markdown]
# #### Now compute back of the envelope calculation for difference in freezing temperature based on mean salinity in upper 10 m

# %%
print(f'adjacent max: {salt_10m_mean_under.max().values}')
print(f'adjacent min: {salt_10m_mean_under.min().values}')
print(f'plume max: {salt_10m_mean_over.max().values}')
print(f'plume min: {salt_10m_mean_over.min().values}')
# Out:
# adjacent max: 30.456980141731826
# adjacent min: 29.402423218598074
# plume max: 25.742380232511767
# plume min: 24.59919690088776

# %%
# Mean salinities (psu)
S_plume = 24.6   # plume waters
S_adj = 29.4     # adjacent waters

# Surface pressure (dbar)
p = 0

SA_plume = gsw.SA_from_SP(S_plume, p, lon=-140, lat=75)  # lon/lat arbitrary at surface
SA_adj = gsw.SA_from_SP(S_adj, p, lon=-140, lat=75)

# Freezing temperature at given salinity and pressure
Tf_plume = gsw.t_freezing(SA_plume, p, saturation_fraction=1.0)
Tf_adj = gsw.t_freezing(SA_adj, p, saturation_fraction=1.0)

print(f"Freezing temperature (plume, 24.6 psu): {Tf_plume:.3f} °C")
print(f"Freezing temperature (adjacent, 29.4 psu): {Tf_adj:.3f} °C")
print(f"Difference in freezing temperature: {Tf_adj - Tf_plume:.3f} °C")
# Out:
# Freezing temperature (plume, 24.6 psu): -1.336 °C
# Freezing temperature (adjacent, 29.4 psu): -1.604 °C
# Difference in freezing temperature: -0.268 °C

# %%
# Parameters
delta_Tf = 0.27      # °C, freezing temperature difference
Q = 100              # W/m², heat loss
H = 10               # m, mixed layer depth
cp = 3990            # J/kg/K, seawater heat capacity
rho = 1027           # kg/m³, seawater density
seconds_per_day = 86400

# Cooling rate (°C/day)
cooling_rate = Q * seconds_per_day / (cp * rho * H)

# Freeze delay (days)
freeze_delay = delta_Tf / cooling_rate
print(f"Expected freeze delay: {freeze_delay:.2f} days")
# Out:
# Expected freeze delay: 1.28 days

# %% [markdown]
# Ian's example:

# %%
# delta T = Q dt / (cp rho H)
# delta T: change in mixed layer temperature Celsius
Q = 200 # W/m2
dt = 86400 # seconds in one day
cp = 3990 # seawater heat capacity, J kg-1 K-1
rho = 1027 # seawater density, kg m-3
H = 10 # mixed layer depth, meters

delta_T = Q * dt / (cp * rho * H)

# %%
# for every 10 meters of mixed layer and 100 W/m-2 heat loss, the mixed layer temperature drops by 0.21 degrees per day
delta_T
# Out:
# 0.4216968907175436

# %%
# freezing temperature divided by rate of temperature loss
1.96 / delta_T
# Out:
# 4.647888194444445

# %% [markdown]
# Using delta T = Q dt / (cp rho H), where
#       delta T: change in mixed layer temperature Celsius
#       H: mixed layer depth (m)
#       Q: heat flux (W m-2)
#       dt: time interval (seconds),
#       cp: seawater heat capacity,  3990 J kg-1 K-1
#       rho: seawater density, 1027 kg m-3,
#
# Then, for every 10 meters of mixed layer and 100 W/m-2 heat loss, the mixed layer temperature drops by 0.21 degrees per day.
#
# Noting that the average Oct-Nov open-water heat fluxes in the study region are ~300 W/m-2, the ML temperature drops by 0.63 degC per day (for every 10 m of mixed layer).
#
# Q: Will sea ice form late because of our too-low seawater freezing point? (Nb, the model can do salinity-dependent freezing point, but not by default. The default freezing point of -1.96C has come down to us through the ages, its origins lost in the mists of time)
#
# A: Assuming a 10 m mixed layer of entirely fresh river water S=0, the model will freeze 3 days too late (3 days to exhaust the “extra” 1.96 degrees C between the ’true’ and model freezing point).  If salinity in the ML is S=15, the model will freeze 1.5 days too late.  If the mixed layer depth in the river plume is only 5 m, then the late freeze delays are halved, to 1.5 and 0.75 days , respectively.
#
# So, probably safe to bound the model freeze delay is +3 days in the river plume (assuming 10 m mixed layer depth of perfectly fresh water).

# %% [markdown]
# ### Function to average over annual mean time series

# %%
def normalize_and_avg_da(da, group_dim='time.year', min_day_dim='days_since_min',
                         time_dim='time'):
    """
    Normalize a DataArray by computing days since the start of each year (or group),
    then compute the mean and std over space and group (e.g., year).

    Parameters:
    -----------
    da : xarray.DataArray
        The input DataArray with dimensions including time and spatial dims.
    group_dim : str
        The time-based group dimension for separation (default: 'time.year').
    min_day_dim : str
        The name for the new time coordinate (default: 'days_since_min').
    time_dim : str
        The name of the time dimension (default: 'time').

    Returns:
    --------
    da_mean : xarray.DataArray
        Mean over space and group. Dims: (days_since_min,)
    da_std : xarray.DataArray
        Std deviation over space and group. Dims: (days_since_min,)
    """
    normalized_list = []

    for group_val, da_group in da.groupby(group_dim):
        days_since = ((da_group[time_dim] - da_group[time_dim].values[0]) /
                      np.timedelta64(1, 'D')).astype(int)
        da_group = da_group.assign_coords({time_dim: days_since.data})
        da_group = da_group.rename({time_dim: min_day_dim})
        da_group = da_group.expand_dims(dim={group_dim.split('.')[-1]: [group_val]})
        normalized_list.append(da_group)

    da_normalized = xr.concat(normalized_list, dim=group_dim.split('.')[-1])
    da_mean = da_normalized.mean(dim=[group_dim.split('.')[-1]])
    da_std = da_normalized.std(dim=[group_dim.split('.')[-1]])

    return da_mean, da_std

# %%
# first take mean for each group
ice_fwc_over_3m_avg = ice_fwc_over_3m.mean(dim=['i','j'])
ice_fwc_under_3m_avg = ice_fwc_under_3m.mean(dim=['i','j'])

ohc_fwc_over_3m_avg = ohc_fwc_over_3m.mean(dim=['i','j'])
ohc_fwc_under_3m_avg = ohc_fwc_under_3m.mean(dim=['i','j'])

ohc_pyc_fwc_over_3m_avg = ohc_pyc_fwc_over_3m.mean(dim=['i','j'])
ohc_pyc_fwc_under_3m_avg = ohc_pyc_fwc_under_3m.mean(dim=['i','j'])

mld_fwc_over_3m_avg = mld_fwc_over_3m.mean(dim=['i','j'])
mld_fwc_under_3m_avg = mld_fwc_under_3m.mean(dim=['i','j'])

strat_fwc_over_3m_avg = strat_fwc_over_3m.mean(dim=['i','j'])
strat_fwc_under_3m_avg = strat_fwc_under_3m.mean(dim=['i','j'])

# %%
# compute normalized datasets and mean/std

# SIC --------------------------
sic_mean_over, sic_std_over = normalize_and_avg_da(ice_fwc_over_3m_avg)
sic_mean_under, sic_std_under = normalize_and_avg_da(ice_fwc_under_3m_avg)

# OHC in surface ML ------------
ohc_mean_over, ohc_std_over = normalize_and_avg_da(ohc_fwc_over_3m_avg)
ohc_mean_under, ohc_std_under = normalize_and_avg_da(ohc_fwc_under_3m_avg)

# OHC in pyc layer -------------
ohc_pyc_mean_over, ohc_pyc_std_over = normalize_and_avg_da(ohc_pyc_fwc_over_3m_avg)
ohc_pyc_mean_under, ohc_pyc_std_under = normalize_and_avg_da(ohc_pyc_fwc_under_3m_avg)

# MLD --------------------------
mld_mean_over, mld_std_over = normalize_and_avg_da(mld_fwc_over_3m_avg)
mld_mean_under, mld_std_under = normalize_and_avg_da(mld_fwc_under_3m_avg)

# stratification ---------------
strat_mean_over, strat_std_over = normalize_and_avg_da(strat_fwc_over_3m_avg)
strat_mean_under, strat_std_under = normalize_and_avg_da(strat_fwc_under_3m_avg)

# %%
def plot_var_mean(ax, var_mean_under, var_std_under, var_mean_over, var_std_over, upper_xy_limits=[80 ,100], title='SIC', ylabel=''):
    # Plot the variable mean + std shading for over and under FWC=2
    var_mean_over.plot(ax=ax, color='tab:blue')
    ax.fill_between(
        var_mean_over.days_since_min,
        var_mean_over - var_std_over,
        var_mean_over + var_std_over,
        color='tab:blue', alpha=0.2)

    var_mean_under.plot(ax=ax, color='k')
    ax.fill_between(
        var_mean_under.days_since_min,
        var_mean_under - var_std_under,
        var_mean_under + var_std_under,
        color='gray', alpha=0.2)

    ax.set_xlim(0, upper_xy_limits[0])
    ax.set_ylim(0, upper_xy_limits[1])
    ax.set_xlabel("")
    ax.set_title(title,size=15)
    ax.set_ylabel(ylabel)

# %%
def plot_sic_diff_shading(ax, sic_mean_over, sic_mean_under):
    diff = sic_mean_over.diff(dim='days_since_min',label="lower") - sic_mean_under.diff(dim='days_since_min',label="lower")
    x = diff['days_since_min']
    y = diff.values

    ax.plot(x, y, color='black',linewidth=0.8)
    ax.fill_between(x, y, 0, where=(y > 0), interpolate=True, color='tab:blue', alpha=0.4, label='Fresher Freezes Faster')
    ax.fill_between(x, y, 0, where=(y < 0), interpolate=True, color='gray', alpha=0.3, label='Saltier Freezes Faster')

    ax.set_xlim(0, 80)
    ax.set_ylim(-3, 4)
    ax.axhline(0, color='black', linewidth=0.8, linestyle='--')
    ax.legend(loc='upper right',fontsize=10)
    ax.set_title("  SIC Rate Difference",size=15)
    ax.set_xlabel("")
    ax.set_ylabel("Δ SIC Rate (%/day)")

# %%
def plot_sic_mean(ax, sic_mean_under, sic_std_under, sic_mean_over, sic_std_over, upper_xy_limits=[80, 100], title='SIC'):
    # Plot the SIC mean + std shading for over and under
    sic_mean_over.plot(ax=ax, color='tab:blue', label='Plume')
    ax.fill_between(
        sic_mean_over.days_since_min,
        sic_mean_over - sic_std_over,
        sic_mean_over + sic_std_over,
        color='tab:blue', alpha=0.2)

    sic_mean_under.plot(ax=ax, color='k', label='Adjacent')
    ax.fill_between(
        sic_mean_under.days_since_min,
        sic_mean_under - sic_std_under,
        sic_mean_under + sic_std_under,
        color='gray', alpha=0.2)

    # Function to find threshold crossings (>= 5 consecutive days > 15%)
    def find_threshold_crossings(sic_mean, threshold=15, min_duration=5):
        above = sic_mean > threshold
        above = above.astype(int).values
        crossings = []

        count = 0
        for i in range(len(above)):
            if above[i]:
                count += 1
                if count == min_duration:
                    crossings.append(sic_mean.days_since_min[i - min_duration + 1].item())
            else:
                count = 0
        return crossings

    # Add vertical lines for each group
    over_thresh = find_threshold_crossings(sic_mean_over)
    ax.axvline(over_thresh, color='tab:blue', linestyle='--', linewidth=1.6)

    under_thresh = find_threshold_crossings(sic_mean_under)
    ax.axvline(under_thresh, color='k', linestyle='--', linewidth=1.6)

    ax.set_xlim(0, upper_xy_limits[0])
    ax.set_ylim(0, upper_xy_limits[1])
    ax.set_yticks([0,25,50,75,100])
    ax.legend(fontsize=10,loc='lower right')
    ax.set_title(title,size=15)
    ax.set_xlabel("")
    ax.set_ylabel("SIC (%)")

    return under_thresh, over_thresh

# %%
# see how many days apart 15% thresholds are
under_thresh, over_thresh = plot_sic_mean(ax, sic_mean_under, sic_std_under, sic_mean_over, sic_std_over, upper_xy_limits=[80, 100], title='SIC')

# %%
under_thresh[0] - over_thresh[0]
# Out:
# 21

# %%
def compute_potential_density(SALT_day, THETA_day, ref_lat=70):
    """
    Compute potential density anomaly referenced to 0 dbar.

    Args:
    - SALT_day: DataArray containing salinity (SALT), longitude (XC), and latitude (YC).
    - THETA_day: DataArray containing potential temperature (THETA).
    - ref_lat: Reference latitude for pressure calculation (default is 70°N).

    Returns:
    - sigma0: Potential density anomaly (kg/m³ - 1000).
    """
    # Convert depth (m) to pressure (dbar)
    p = gsw.p_from_z(SALT_day.Z, ref_lat)  # Depth is negative

    # Convert Practical Salinity (SP) to Absolute Salinity (SA)
    SA = gsw.SA_from_SP(SALT_day, p, SALT_day.XC, SALT_day.YC)

    # Convert Potential Temperature to Conservative Temperature
    CT = gsw.conversions.CT_from_pt(SA, THETA_day)

    # Calculate potential density anomaly referenced to 0 dbar
    sigma0 = gsw.sigma0(SA, CT)

    # Add metadata
    sigma0.name = 'potential_density'
    sigma0.attrs['long_name'] = 'potential_density'

    return sigma0 + 1000

# %%
# calculate potential density from in situ density
sigma = compute_potential_density(SALT_zarr_day.SALT, THETA_zarr_day.THETA, ref_lat=70)

# %%
# make depth positive downward
sigma = sigma.assign_coords(Z = sigma.Z * -1)

# subtract 1000
sigma = sigma - 1000

# %%
plt.rcParams['font.size'] = 13

# Set up figure with custom GridSpec
fig = plt.figure(figsize=(15, 5))  # Adjust width for added profile
gs = gridspec.GridSpec(2, 4, figure=fig, width_ratios=[1, 1, 1, 0.55], wspace=0.42, hspace=0.3)

# Create 2x3 grid axes
axs = [fig.add_subplot(gs[i, j]) for i in range(2) for j in range(3)]

# Create the extra axis for vertical profile (spanning both rows)
ax_profile = fig.add_subplot(gs[:, 3])

# Add subplot labels (a)-(g)
for i, ax in enumerate(axs):
    label = f"({string.ascii_lowercase[i]})"
    ax.text(0, 1.15, label, transform=ax.transAxes,
            fontsize=15, va='top', ha='left')

# Plot data into axs[0] through axs[5]
plot_sic_mean(axs[0], sic_mean_under, sic_std_under, sic_mean_over, sic_std_over)
plot_var_mean(axs[1], ohc_mean_under, ohc_std_under, ohc_mean_over, ohc_std_over,
              upper_xy_limits=[80, 600], title='OHC$_s$', ylabel='OHC (MJ m$^{-2}$)')
plot_var_mean(axs[2], mld_mean_under, mld_std_under, mld_mean_over, mld_std_over,
              upper_xy_limits=[80, 30], title='MLD', ylabel='Depth (m)')
plot_sic_diff_shading(axs[3], sic_mean_over, sic_mean_under)
plot_var_mean(axs[4], ohc_pyc_mean_under, ohc_pyc_std_under, ohc_pyc_mean_over, ohc_pyc_std_over,
              upper_xy_limits=[80, 1000], title='OHC$_p$', ylabel='OHC (MJ m$^{-2}$)')
plot_var_mean(axs[5], strat_mean_under, strat_std_under, strat_mean_over, strat_std_over,
              upper_xy_limits=[80, 10], title='Stratification', ylabel=r'$\Delta \sigma_{\theta}$ (kg m$^{-2}$)')

# Plot vertical profile into ax_profile
plt.rcParams['font.size'] = 9
# sigma.sel(time='2015-10-01', i=660, j=130).plot(ax=ax_profile, y='Z', marker='o', color='k', markersize=2, label='FWC=1.7m')
# sigma.sel(time='2015-10-01', i=560, j=200).plot(ax=ax_profile, y='Z', marker='o', color='tab:blue', markersize=2, label='FWC=3.9m')
sigma.sel(time='2015-10-01', i=660, j=130).plot(ax=ax_profile, y='Z', marker='o', color='k', markersize=2, label='FWC<3m')
sigma.sel(time='2015-10-01', i=560, j=200).plot(ax=ax_profile, y='Z', marker='o', color='tab:blue', markersize=2, label='FWC>3m')

# Surface MLD lines
ax_profile.axhline(y=mld_da.mld.sel(time='2015-10-01', i=660, j=130).values * -1, linestyle='dashed', color='k', linewidth=1)
ax_profile.axhline(y=mld_da.mld.sel(time='2015-10-01', i=560, j=200).values * -1, linestyle='dashed', color='tab:blue', linewidth=1)

# Winter MLD
pcy_depth = sigma.isel(k=19).Z.values
ax_profile.axhline(y=pcy_depth, color='gray', linewidth=1)

# Add text labels
ax_profile.text(18, 4, 'MLD', size=10, color='tab:blue')
ax_profile.text(18, 16, 'MLD', size=10, color='k')
ax_profile.text(15, 76, 'Pycnocline Base', size=10, color='gray')

# Set axis properties
ax_profile.set_title('')
ax_profile.set_title('(g)', loc='left', size=15)
ax_profile.set_yticks(np.arange(0,110,20))
ax_profile.legend(fontsize=10,loc='center left')
ax_profile.set_ylabel("Depth (m)")
ax_profile.set_xlabel(r"$\sigma_{\theta}$", size=16)
ax_profile.set_ylim(100, 0)
ax_profile.set_xlim(14, 26.5)

axs[0].set_xticklabels("")
axs[1].set_xticklabels("")
axs[2].set_xticklabels("")

axs[1].set_yticks([0,200,400,600])
axs[2].set_yticks([0,10,20,30])
# axs[4].set_yticks([0,100,200,300])

# Shared X-axis label
fig.text(0.34, -0.01, "Days Following Sea Ice Minimum", size=13);

# Save final combined figure
# fig.savefig('/home/jpluser/git_repos/SASSIE_ECCO_salinity_stratification/figures/combined_time_series_and_profile.png',
#             dpi=300, bbox_inches='tight')
# fig.savefig('/home/jpluser/git_repos/SASSIE_ECCO_salinity_stratification/figures/fig4.png',
#             dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Divide by square root N for shading

# %%
plt.rcParams['font.size'] = 15

# Set up figure with custom GridSpec
fig = plt.figure(figsize=(14.5, 5))  # Adjust width for added profile
gs = gridspec.GridSpec(2, 4, figure=fig, width_ratios=[1, 1, 1, 0.56], wspace=0.42, hspace=0.3)

# Create 2x3 grid axes
axs = [fig.add_subplot(gs[i, j]) for i in range(2) for j in range(3)]

# Create the extra axis for vertical profile (spanning both rows)
ax_profile = fig.add_subplot(gs[:, 3])

# Add subplot labels (a)-(g)
for i, ax in enumerate(axs):
    label = f"({string.ascii_lowercase[i]})"
    ax.text(-0.03, 1.15, label, transform=ax.transAxes,
            fontsize=15, va='top', ha='left')

# Plot data into axs[0] through axs[5]
plot_sic_mean(axs[0], sic_mean_under, sic_std_under/np.sqrt(7), sic_mean_over, sic_std_over/np.sqrt(7))
plot_var_mean(axs[1], ohc_mean_under, ohc_std_under/np.sqrt(7), ohc_mean_over, ohc_std_over/np.sqrt(7),
              upper_xy_limits=[80, 400], title='OHC$_s$', ylabel='OHC (MJ m$^{-2}$)')
plot_var_mean(axs[2], mld_mean_under, mld_std_under/np.sqrt(7), mld_mean_over, mld_std_over/np.sqrt(7),
              upper_xy_limits=[80, 20], title='MLD', ylabel='Depth (m)')
plot_sic_diff_shading(axs[3], sic_mean_over, sic_mean_under)
plot_var_mean(axs[4], ohc_pyc_mean_under, ohc_pyc_std_under/np.sqrt(7), ohc_pyc_mean_over, ohc_pyc_std_over/np.sqrt(7),
              upper_xy_limits=[80, 800], title='OHC$_p$', ylabel='OHC (MJ m$^{-2}$)')
plot_var_mean(axs[5], strat_mean_under, strat_std_under/np.sqrt(7), strat_mean_over, strat_std_over/np.sqrt(7),
              upper_xy_limits=[80, 8], title='Stratification', ylabel=r'$\Delta \sigma_{\theta}$ (kg m$^{-2}$)')

# Plot vertical profile into ax_profile
plt.rcParams['font.size'] = 9
sigma.sel(time='2015-10-01', i=660, j=130).plot(ax=ax_profile, y='Z', marker='o', color='k', markersize=2, label='FWC<3m')
sigma.sel(time='2015-10-01', i=560, j=200).plot(ax=ax_profile, y='Z', marker='o', color='tab:blue', markersize=2, label='FWC>3m')

# Surface MLD lines
ax_profile.axhline(y=mld_da.mld.sel(time='2015-10-01', i=660, j=130).values * -1, linestyle='dashed', color='k', linewidth=1)
ax_profile.axhline(y=mld_da.mld.sel(time='2015-10-01', i=560, j=200).values * -1, linestyle='dashed', color='tab:blue', linewidth=1)

# Winter MLD
pcy_depth = sigma.isel(k=19).Z.values
ax_profile.axhline(y=pcy_depth, color='gray', linewidth=1)

# Add text labels
ax_profile.text(18, 4, 'MLD', size=13, color='tab:blue')
ax_profile.text(18, 16, 'MLD', size=13, color='k')
ax_profile.text(15, 88, 'Pycnocline\nBase', size=13, color='gray')

# Set axis properties
ax_profile.set_title('')
ax_profile.set_title('(g)', loc='left', size=15)
ax_profile.set_yticks(np.arange(0,110,20))
ax_profile.legend(fontsize=10,loc='center left')
ax_profile.set_ylabel("Depth (m)")
ax_profile.set_xlabel(r"$\sigma_{\theta}$", size=18, labelpad=10)
ax_profile.set_ylim(100, 0)
ax_profile.set_xlim(14, 26.5)

axs[0].set_xticklabels("")
axs[1].set_xticklabels("")
axs[2].set_xticklabels("")

axs[1].set_yticks([0,100,200,300,400])
axs[2].set_ylim([5,20])
axs[2].set_yticks([5,10,15,20])
axs[4].set_ylim([200,800])
axs[4].set_yticks([200,400,600,800])

# Shared X-axis label
fig.text(0.34, -0.01, "Days Following Sea Ice Minimum", size=15);

# Save final combined figure
fig.savefig('/home/jpluser/git_repos/SASSIE_ECCO_salinity_stratification/figures/fig4.png',
            dpi=300, bbox_inches='tight')

# %% [markdown]
# ***

# %%
# inspect OHC_p - PLUME
fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=[13,3],layout='constrained')
ohc_pyc_fwc_over_3m.sel(time='2020-09-30').plot(ax=ax1,vmin=400,vmax=800);
ohc_pyc_fwc_over_3m.sel(time='2020-10-30').plot(ax=ax2,vmin=400,vmax=800);
ohc_pyc_fwc_over_3m.sel(time='2020-11-30').plot(ax=ax3,vmin=400,vmax=800);
ohc_pyc_fwc_over_3m.sel(time='2020-12-30').plot(ax=ax4,vmin=400,vmax=800);

for ax in (ax1,ax2,ax3,ax4):
    ax.set_ylabel("")
    ax.set_xlabel("")
    ax.set_title("")

# %%
# inspect OHC_p - ADJ
fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=[13,3],layout='constrained')
ohc_pyc_fwc_under_3m.sel(time='2020-09-30').plot(ax=ax1,vmin=100,vmax=800);
ohc_pyc_fwc_under_3m.sel(time='2020-10-30').plot(ax=ax2,vmin=100,vmax=800);
ohc_pyc_fwc_under_3m.sel(time='2020-11-30').plot(ax=ax3,vmin=100,vmax=800);
ohc_pyc_fwc_under_3m.sel(time='2020-12-30').plot(ax=ax4,vmin=100,vmax=800);

for ax in (ax1,ax2,ax3,ax4):
    ax.set_ylabel("")
    ax.set_xlabel("")
    ax.set_title("")

# %%
ohc_pyc_fwc_under_3m.where(ohc_pyc_fwc_under_3m==0).sel(time='2020-09-30').plot();
plt.scatter(530,355,color='r')

# %%
SALT_zarr_day.SALT.sel(i=530,j=355,time='2020-09-30').plot(y='Z')
plt.ylim(-25,0);

# %% [markdown]
# ### Add points instead of shading

# %%
def normalize_da_by_year(da, group_dim='time.year', min_day_dim='days_since_min', time_dim='time'):
    """
    Normalize a DataArray by computing days since the start of each group (e.g., year).

    Parameters:
    -----------
    da : xarray.DataArray
        Input DataArray with a time dimension.
    group_dim : str
        Time-based group specifier, e.g., 'time.year' (default).
    min_day_dim : str
        Name for the new normalized time coordinate (default: 'days_since_min').
    time_dim : str
        Name of the time dimension (default: 'time').

    Returns:
    --------
    da_normalized : xarray.DataArray
        DataArray with the time coordinate replaced by days since the start of each group,
        and a new dimension for the group (e.g., year).
    """
    normalized_list = []

    for group_val, da_group in da.groupby(group_dim):
        # Calculate days since the start of the group
        days_since = ((da_group[time_dim] - da_group[time_dim].values[0]) /
                      np.timedelta64(1, 'D')).astype(int)

        # Assign new time coordinate and rename it
        da_group = da_group.assign_coords({time_dim: days_since.data})
        da_group = da_group.rename({time_dim: min_day_dim})

        # Add the group (e.g., year) as a dimension
        group_name = group_dim.split('.')[-1]
        da_group = da_group.expand_dims(dim={group_name: [group_val]})

        normalized_list.append(da_group)

    # Concatenate all groups into a single DataArray
    da_normalized = xr.concat(normalized_list, dim=group_dim.split('.')[-1])

    return da_normalized

# %%
# normalize raw data for points

ice_fwc_over_3m_norm = normalize_da_by_year(ice_fwc_over_3m)
ice_fwc_under_3m_norm = normalize_da_by_year(ice_fwc_under_3m)

# %%
# compute normalized datasets for points

# SIC
sic_norm_over = normalize_da_by_year(ice_fwc_over_3m)
sic_norm_under = normalize_da_by_year(ice_fwc_under_3m)

# OHC in surface ML
ohc_norm_over = normalize_da_by_year(ohc_fwc_over_3m)
ohc_norm_under = normalize_da_by_year(ohc_fwc_under_3m)

# OHC above winter ML
ohc_pyc_norm_over = normalize_da_by_year(ohc_pyc_fwc_over_3m)
ohc_pyc_norm_under = normalize_da_by_year(ohc_pyc_fwc_under_3m)

# MLD
mld_norm_over = normalize_da_by_year(mld_fwc_over_3m)
mld_norm_under = normalize_da_by_year(mld_fwc_under_3m)

# stratification
strat_norm_over = normalize_da_by_year(strat_fwc_over_3m)
strat_norm_under = normalize_da_by_year(strat_fwc_under_3m)

# %%
sic_norm_over.isel(j=slice(None,None,100),i=slice(None,None,100)).plot.scatter(x='days_since_min',color='tab:blue', alpha=0.2);

# %% [markdown]
# ### Every 100 points

# %%
# modified function with points instead of SE/Std shading
def plot_var_mean(ax, var_mean_under, var_norm_under, var_mean_over, var_norm_over, upper_xy_limits=[80 ,100], title='SIC', ylabel=''):
    # Plot the variable mean + std shading for over and under FWC=2
    var_mean_over.plot(ax=ax, color='tab:blue')
    var_norm_over.isel(j=slice(None,None,100),i=slice(None,None,100)).plot.scatter(ax=ax, x='days_since_min',color='tab:blue', alpha=0.2);
    var_mean_under.plot(ax=ax, color='k')
    var_norm_under.isel(j=slice(None,None,100),i=slice(None,None,100)).plot.scatter(ax=ax, x='days_since_min',color='gray', alpha=0.2);

    ax.set_xlim(0, upper_xy_limits[0])
    ax.set_ylim(0, upper_xy_limits[1])
    ax.set_xlabel("")
    ax.set_title(title,size=14)
    ax.set_ylabel(ylabel)

# %%
def plot_sic_mean(ax, sic_mean_under, sic_norm_under, sic_mean_over, sic_norm_over, upper_xy_limits=[80, 100], title='SIC'):
    # Plot the SIC mean + std shading for over and under
    sic_mean_over.plot(ax=ax, color='tab:blue', label='Plume')
    sic_norm_over.isel(j=slice(None,None,100),i=slice(None,None,100)).plot.scatter(ax=ax, x='days_since_min',color='tab:blue', alpha=0.2);

    sic_mean_under.plot(ax=ax, color='k', label='Adjacent')
    sic_norm_under.isel(j=slice(None,None,100),i=slice(None,None,100)).plot.scatter(ax=ax, x='days_since_min',color='gray', alpha=0.2);
    
    # Function to find threshold crossings (>= 5 consecutive days > 15%)
    def find_threshold_crossings(sic_mean, threshold=15, min_duration=5):
        above = sic_mean > threshold
        above = above.astype(int).values
        crossings = []

        count = 0
        for i in range(len(above)):
            if above[i]:
                count += 1
                if count == min_duration:
                    crossings.append(sic_mean.days_since_min[i - min_duration + 1].item())
            else:
                count = 0
        return crossings

    # Add vertical lines for each group
    over_thresh = find_threshold_crossings(sic_mean_over)
    ax.axvline(over_thresh, color='tab:blue', linestyle='--', linewidth=1.6)

    under_thresh = find_threshold_crossings(sic_mean_under)
    ax.axvline(under_thresh, color='k', linestyle='--', linewidth=1.6)

    ax.set_xlim(0, upper_xy_limits[0])
    ax.set_ylim(0, upper_xy_limits[1])
    ax.legend(fontsize=10,loc='lower right')
    ax.set_title(title,size=13)
    ax.set_xlabel("")
    ax.set_ylabel("Sea Ice Conc (%)")

    return under_thresh, over_thresh

# %%
plt.rcParams['font.size'] = 13

# Set up figure with custom GridSpec
fig = plt.figure(figsize=(15, 5))  # Adjust width for added profile
gs = gridspec.GridSpec(2, 4, figure=fig, width_ratios=[1, 1, 1, 0.55], wspace=0.38, hspace=0.3)

# Create 2x3 grid axes
axs = [fig.add_subplot(gs[i, j]) for i in range(2) for j in range(3)]

# Create the extra axis for vertical profile (spanning both rows)
ax_profile = fig.add_subplot(gs[:, 3])

# Add subplot labels (a)-(g)
for i, ax in enumerate(axs):
    label = f"({string.ascii_lowercase[i]})"
    ax.text(0, 1.13, label, transform=ax.transAxes,
            fontsize=15, va='top', ha='left')

# Plot data into axs[0] through axs[5]
plot_sic_mean(axs[0], sic_mean_under, sic_norm_under, sic_mean_over, sic_norm_over)
plot_var_mean(axs[1], ohc_mean_under, ohc_norm_under, ohc_mean_over, ohc_norm_over,
              upper_xy_limits=[80, 300], title='OHC$_s$', ylabel='OHC (MJ m$^{-2}$)')
plot_var_mean(axs[2], mld_mean_under, mld_norm_under, mld_mean_over, mld_norm_over,
              upper_xy_limits=[80, 30], title='MLD', ylabel='Depth (m)')
plot_sic_diff_shading(axs[3], sic_mean_over, sic_mean_under)
plot_var_mean(axs[4], ohc_pyc_mean_under, ohc_pyc_norm_under, ohc_pyc_mean_over, ohc_pyc_norm_over,
              upper_xy_limits=[80, 300], title='OHC$_p$', ylabel='OHC (MJ m$^{-2}$)')
plot_var_mean(axs[5], strat_mean_under, strat_norm_under, strat_mean_over, strat_norm_over,
              upper_xy_limits=[80, 10], title='Stratification', ylabel=r'$\Delta \sigma_{\theta}$ (kg m$^{-2}$)')

# Plot vertical profile into ax_profile
plt.rcParams['font.size'] = 9
sigma.sel(time='2015-10-01', i=660, j=130).plot(ax=ax_profile, y='Z', marker='o', color='k', markersize=2, label='FWC<3m')
sigma.sel(time='2015-10-01', i=560, j=200).plot(ax=ax_profile, y='Z', marker='o', color='tab:blue', markersize=2, label='FWC>3m')

# Surface MLD lines
ax_profile.axhline(y=mld_da.mld.sel(time='2015-10-01', i=660, j=130).values * -1, linestyle='dashed', color='k', linewidth=1)
ax_profile.axhline(y=mld_da.mld.sel(time='2015-10-01', i=560, j=200).values * -1, linestyle='dashed', color='tab:blue', linewidth=1)

# Winter MLD
ax_profile.axhline(y=sigma.isel(k=9).Z.values, color='gray', linewidth=1)

# Add text labels
ax_profile.text(18, 5, 'MLD', size=10, color='tab:blue')
ax_profile.text(18, 11, 'MLD', size=10, color='k')
ax_profile.text(15, 17, 'Winter MLD', size=10, color='gray')

# Set axis properties
ax_profile.set_title('')
ax_profile.set_title('(g)', loc='left', size=15)
ax_profile.set_yticks([0, 10, 20, 30, 40])
ax_profile.legend(fontsize=10)
ax_profile.set_ylabel("Depth (m)")
ax_profile.set_xlabel(r"$\sigma_{\theta}$", size=16)
ax_profile.set_ylim(40, 0)
ax_profile.set_xlim(14, 26)

axs[0].set_xticklabels("")
axs[1].set_xticklabels("")
axs[2].set_xticklabels("")

axs[1].set_yticks([0,100,200,300])
axs[2].set_yticks([0,10,20,30])
axs[4].set_yticks([0,100,200,300])

# Shared X-axis label
fig.text(0.34, -0.01, "Days Following Sea Ice Minimum", size=13);

# Save final combined figure
# fig.savefig('/home/jpluser/git_repos/SASSIE_ECCO_salinity_stratification/figures/combined_time_series_and_profile.png',
#             dpi=300, bbox_inches='tight')
# fig.savefig('/home/jpluser/git_repos/SASSIE_ECCO_salinity_stratification/figures/fig4.png',
#             dpi=300, bbox_inches='tight')
