# %% [markdown]
# # Combined time series figure

# %%
## import required packages
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.lines import Line2D
import matplotlib.ticker as ticker
import warnings
warnings.filterwarnings("ignore", module='distributed')

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:35141")
client
# Out:
# <Client: 'tcp://127.0.0.1:35141' processes=8 threads=32, memory=123.95 GiB>
# Task exception was never retrieved
# future: <Task finished name='Task-15379' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15330' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15384' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15337' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15341' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15375' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15380' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15388' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15324' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15321' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15366' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15348' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15368' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15401' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15400' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15398' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15395' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15393' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15391' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15390' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15386' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15385' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15382' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15381' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15378' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15377' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15376' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15374' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15373' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15372' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15371' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15370' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15369' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15367' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15365' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15364' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15363' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15362' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15361' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15360' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15359' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15358' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15357' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15355' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15354' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15353' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15352' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15351' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15350' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15349' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15347' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15346' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15345' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15343' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15342' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15340' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15339' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15338' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15336' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15335' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15334' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15333' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15332' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15331' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15329' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15328' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15327' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15326' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15325' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15323' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15322' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15320' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15319' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15318' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15317' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15403' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15402' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15399' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15397' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15396' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15394' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15392' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15389' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15387' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-15383' coro=<Client._gather.<locals>.wait() done, defined at /home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/jpluser/miniforge3/envs/jupyter/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
# initialize s3 filesystem
s3_options = dict(anon=False)

# %%
# open geometry file for HH field
HH_grid = xr.open_dataset("~/efs-mount-point/mzahn/sassie/HH/GRID/GRID_GEOMETRY_SASSIE_HH_V1R1_NATIVE_LLC1080.nc")

# %%
# function to open zarr store with a provided s3 bucket path
def open_zarr_store(s3_path, s3_options):
    # initalize s3 file system
    s3 = s3fs.S3FileSystem(**s3_options)

    # define location of zarr store and openover_2m
    store = s3fs.S3Map(root=s3_path, s3=s3, check=False)
    zarr_store = xr.open_zarr(store)
    
    return zarr_store

# %% [markdown]
# ### Open ZARR datasets

# %%
# open FWC dataset
fwc_yrs_masked = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/FWC/FWC_masked_Beaufort_final.ZARR')
fwc_yrs_masked = fwc_yrs_masked.fwc

# %%
sic_ds = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/SIC/SIC_masked_Beaufort.ZARR')

ice_fwc_over_2m = sic_ds.sic.where(fwc_yrs_masked>2).load()
ice_fwc_under_2m = sic_ds.sic.where(fwc_yrs_masked<2).load()

# %%
# open OHC zarr stores
ohc_mld_ds = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/OHC/OHC_MLD_Beaufort_final.ZARR')
ohc_mld_pyc_ds = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/OHC/OHC_PYC_Beaufort_final.ZARR')

# select all cells with FWC above and below 2
ohc_fwc_over_2m =(ohc_mld_ds.ohc/1e6).where(fwc_yrs_masked>2).load() # convert J to MJ
ohc_fwc_under_2m = (ohc_mld_ds.ohc/1e6).where(fwc_yrs_masked<2).load() # convert J to MJ

ohc_pyc_fwc_over_2m = (ohc_mld_pyc_ds.ohc_pyc/1e6).where(fwc_yrs_masked>2).load()
ohc_pyc_fwc_under_2m = (ohc_mld_pyc_ds.ohc_pyc/1e6).where(fwc_yrs_masked<2).load()

# %%
mld_da = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/MLD/MLD_Beaufort_final.ZARR')

# select all cells with FWC above and below 2
mld_fwc_over_2m = (mld_da.mld.where(fwc_yrs_masked>2)*-1).load()
mld_fwc_under_2m = (mld_da.mld.where(fwc_yrs_masked<2)*-1).load()

# %%
strat_da = xr.open_zarr('/home/jpluser/efs-mount-point/mzahn/sassie/HH/ZARR/STRAT/STRAT_Beaufort.ZARR')

# select all cells with FWC>2
strat_fwc_over_2m = strat_da.sigma.where(fwc_yrs_masked>2).load()
strat_fwc_under_2m = strat_da.sigma.where(fwc_yrs_masked<2).load()

# %% [markdown]
# ### Add vertical lines for where SIC>=15% and remain above it for at least 5 days

# %%
# first day when sea ice concentration (SIC) reaches or exceeds 15% and stays above that threshold for at least 5 consecutive days
years = np.arange(2014, 2021)

ice_fwc_over_2m_dates = []
ice_fwc_under_2m_dates = []

for year in years:
    # Compute mean SIC over space
    ice_over_mean = ice_fwc_over_2m.sel(time=str(year)).mean(dim=['i', 'j'], skipna=True).compute()
    ice_under_mean = ice_fwc_under_2m.sel(time=str(year)).mean(dim=['i', 'j'], skipna=True).compute()
    
    # Convert to boolean where SIC >= 15
    ice_over_bool = ice_over_mean >= 15
    ice_under_bool = ice_under_mean >= 15

    # Find the first day where there are 5+ consecutive True values
    def find_persistent_threshold(bool_array, time_array, window=5):
        bool_np = bool_array.values
        for i in range(len(bool_np) - window + 1):
            if np.all(bool_np[i:i+window]):
                return time_array[i].values
        return np.datetime64('NaT')  # If no valid period found

    over_time = ice_over_mean['time']
    under_time = ice_under_mean['time']

    ice_over_date = find_persistent_threshold(ice_over_bool, over_time)
    ice_under_date = find_persistent_threshold(ice_under_bool, under_time)

    ice_fwc_over_2m_dates.append(ice_over_date)
    ice_fwc_under_2m_dates.append(ice_under_date)

# %% [markdown]
# ## Combined plot

# %%
def compute_aligned_stats(data_over, data_under, year):
    # Select data for a specific year
    data_over_yr = data_over.sel(time=str(year))
    data_under_yr = data_under.sel(time=str(year))

    # Find the first valid sea ice day (non-NaN mean)
    mean_over = data_over_yr.mean(dim=['i', 'j'])
    first_valid_index = mean_over.notnull().argmax().compute().item()

    # Slice data from that index onward
    mean_over = mean_over.isel(time=slice(first_valid_index, None))
    mean_under = data_under_yr.mean(dim=['i', 'j']).isel(time=slice(first_valid_index, None))

    # std_over = data_over_yr.isel(time=slice(first_valid_index, None)).std(dim=['i', 'j'])
    # std_under = data_under_yr.isel(time=slice(first_valid_index, None)).std(dim=['i', 'j'])

    x = np.arange(len(mean_over))  # relative day index

    # return x, mean_over, std_over, mean_under, std_under
    return x, mean_over, mean_under

def plot_variable_row(fig, axes_row, year, variable_pairs, titles, ice_fwc_over_2m_dates, ice_fwc_under_2m_dates, row_idx):
    for j, ((data_over, data_under), title) in enumerate(zip(variable_pairs, titles)):
        ax = axes_row[j]
        # x, mean_over, std_over, mean_under, std_under = compute_aligned_stats(data_over, data_under, year)
        x, mean_over, mean_under = compute_aligned_stats(data_over, data_under, year)

        ax.plot(x, mean_over, color='tab:blue', label='FWC > 2m')
        # ax.fill_between(x, mean_over - std_over/np.sqrt(7), mean_over + std_over/np.sqrt(7), color='tab:blue', alpha=0.3)

        ax.plot(x, mean_under, color='k', label='FWC < 2m')
        # ax.fill_between(x, mean_under - std_under/np.sqrt(7), mean_under + std_under/np.sqrt(7), color='gray', alpha=0.2)

        ax.set_xlim([0, 60])
        ax.grid(True)

        if j == 0:
            ax.set_ylabel(f"{year}", rotation=0, labelpad=30, fontsize=16)
            ax.axvline(x=np.where(mean_over.time.values == ice_fwc_over_2m_dates[row_idx])[0][0],color='tab:blue',linestyle='dashed')
            ax.axvline(x=np.where(mean_under.time.values == ice_fwc_under_2m_dates[row_idx])[0][0],color='k',linestyle='dashed')
            
        if year == 2014:
            ax.set_title(title, fontsize=16)

# %%
years = np.arange(2014, 2021)
nrows, ncols = len(years), 5

# Your variable list: each is a tuple (over_2m, under_2m)
variable_pairs = [
    (ice_fwc_over_2m, ice_fwc_under_2m),
    (ohc_fwc_over_2m, ohc_fwc_under_2m),
    (ohc_pyc_fwc_over_2m, ohc_pyc_fwc_under_2m),
    (mld_fwc_over_2m, mld_fwc_under_2m),
    (strat_fwc_over_2m, strat_fwc_under_2m)
]

variable_titles = [
    'SIC\n(%)',
    'OHC$_s$\n(MJ m$^{-2}$)',
    'OHC$_p$\n(MJ m$^{-2}$)',
    'MLD\n(m)',
    'Stratification, $\Delta \\sigma_{\\theta}$\n(kg m$^{-2}$)'
]

# --- Create figure ---
plt.rcParams['font.size'] = 13
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14.5, 14), sharex=True, sharey='col')

# Plot each row/year
for i, year in enumerate(years):
    plot_variable_row(fig, axes[i], year, variable_pairs, variable_titles, ice_fwc_over_2m_dates, ice_fwc_under_2m_dates, row_idx=i)

# Custom legend in one corner subplot
custom_lines = [Line2D([0], [0], color='tab:blue', lw=2), \
                Line2D([0], [0], color='k', lw=2), \
                Line2D([0], [0], color='tab:blue', lw=2, linestyle='dashed'), \
                Line2D([0], [0], color='k', lw=2, linestyle='dashed')]
# axes[-1, -1].legend(custom_lines, ['FWC > 2m', 'FWC < 2m'], loc='upper right', fontsize=10)

fig.legend(
    custom_lines,
    # ['FWC > 2m', 'FWC < 2m', 'Day when SIC>15% for FWC > 2m', 'Day when SIC>15% for FWC < 2m'],
    ['Plume', 'Adjacent', 'Day when SIC>15% for Plume', 'Day when SIC>15% for Adjacent'],
    loc='lower center',
    bbox_to_anchor=(0.5, -0.01),  # adjust Y as needed
    ncol=4,
    fontsize=15,
    frameon=False  # optional: no box around legend
)

# Set consistent y-axis limits per column
axes[0,0].set_ylim(0,100)
axes[0,1].set_ylim(0,500)
axes[0,1].set_yticks([0,250,500])
axes[0,2].set_ylim(200,1000)
axes[0,2].set_yticks([200,600,1000])
axes[0,3].set_ylim(0,30)
axes[0,3].set_yticks([0,15,30])
axes[0,4].set_ylim(0,15)

# --- Add shared x-label ---
fig.text(0.5, 0.04, 'Days Following Sea Ice Minimum', ha='center', fontsize=16)

# for col in range(ncols-1):
#     for row in range(nrows):
#         ax = axes[row, col]
#         labels = ax.get_yticklabels()
        # for i, label in enumerate(labels):
        #     if i % 2 == 1:  # hide every other label (e.g., odd-indexed ones)
        #         label.set_visible(False)

# Tight layout with room for x-label
plt.tight_layout(rect=[0, 0.05, 1, 0.96])
plt.subplots_adjust(wspace=0.35) 
plt.show()

fig.savefig('/home/jpluser/git_repos/SASSIE_ECCO_salinity_stratification/figures/fwc_group_time_series.png', \
            dpi=300, bbox_inches='tight')
# fig.savefig('/home/jpluser/git_repos/SASSIE_ECCO_salinity_stratification/figures/figS3.png', \
#             dpi=300, bbox_inches='tight')

# %%
# check out OHC in 2018 and 2020
fig, (ax1,ax2) = plt.subplots(1,2,figsize=[10,4],layout='constrained')
ohc_pyc_fwc_over_2m.sel(time='2016').isel(time=0).plot(ax=ax1,vmin=100,vmax=2000);
ohc_pyc_fwc_under_2m.sel(time='2016').isel(time=0).plot(ax=ax2,vmin=100,vmax=2000);

# %%
# check out OHC in 2018 and 2020
fig, (ax1,ax2) = plt.subplots(1,2,figsize=[10,4],layout='constrained')
ohc_pyc_fwc_over_2m.sel(time='2018').isel(time=0).plot(ax=ax1,vmin=100,vmax=2000);
ohc_pyc_fwc_under_2m.sel(time='2018').isel(time=0).plot(ax=ax2,vmin=100,vmax=2000);

# %%
# check out OHC in 2018 and 2020
fig, (ax1,ax2) = plt.subplots(1,2,figsize=[10,4],layout='constrained')
ohc_pyc_fwc_over_2m.sel(time='2020').isel(time=0).plot(ax=ax1,vmin=100,vmax=2000);
ohc_pyc_fwc_under_2m.sel(time='2020').isel(time=0).plot(ax=ax2,vmin=100,vmax=2000);

# %% [markdown]
# ### Open ZARR datasets

# %%
import s3fs

# %%
# function to open zarr store with a provided s3 bucket path
def open_zarr_store(s3_path, s3_options):
    # initalize s3 file system
    s3 = s3fs.S3FileSystem(**s3_options)

    # define location of zarr store and open
    store = s3fs.S3Map(root=s3_path, s3=s3, check=False)
    zarr_store = xr.open_zarr(store)
    
    return zarr_store

# %%
# open SALT zarr store - [psu]
SALT_zarr_day = open_zarr_store('s3://ecco-processed-data/SASSIE/N1/HH/ZARR/SALT_AVG_DAILY.ZARR/', s3_options)

# open THETA zarr store - [degC]
THETA_zarr_day = open_zarr_store('s3://ecco-processed-data/SASSIE/N1/HH/ZARR/THETA_AVG_DAILY.ZARR/', s3_options)

# %%
theta_da = THETA_zarr_day.THETA

# %%
# check out theta in 2018 and 2020
fig, (ax1,ax2) = plt.subplots(1,2,figsize=[10,4],layout='constrained')
theta_da.isel(i=slice(510,750),j=slice(110,390)).sel(time='2018-09-21').isel(k=10).plot(ax=ax1,vmin=-2,vmax=7);
theta_da.isel(i=slice(510,750),j=slice(110,390)).sel(time='2020-09-21').isel(k=10).plot(ax=ax2,vmin=-2,vmax=7);

# %%
theta_beaufort = theta_da.isel(i=slice(510,750),j=slice(110,390))

# %%
print(theta_beaufort.isel(k=10).Z.values)
print(theta_beaufort.isel(k=17).Z.values)
# Out:
# -21.125
# -60.28

# %%
theta_00m_monthly = theta_beaufort.isel(k=0).mean(dim=['i', 'j']).resample(time='1MS').mean().compute()
theta_20m_monthly = theta_beaufort.isel(k=10).mean(dim=['i', 'j']).resample(time='1MS').mean().compute()
theta_60m_monthly = theta_beaufort.isel(k=17).mean(dim=['i', 'j']).resample(time='1MS').mean().compute()

# %%
# plot time series of theta at surface, 20, and 60 m
fig, ax1 = plt.subplots(1,1,figsize=[10,3])

theta_00m_monthly.plot(ax=ax1,label='Surface')
theta_20m_monthly.plot(ax=ax1,label='20 m')
theta_60m_monthly.plot(ax=ax1,label='60 m')

plt.title("")
plt.grid(linestyle='dashed',linewidth=0.5)
plt.legend(ncol=3);

# %%
theta_Sbeaufort = theta_da.isel(i=slice(510,600),j=slice(110,390))

# %%
theta_00m_monthly = theta_Sbeaufort.isel(k=0).mean(dim=['i', 'j']).resample(time='1MS').mean().compute()
theta_20m_monthly = theta_Sbeaufort.isel(k=10).mean(dim=['i', 'j']).resample(time='1MS').mean().compute()
theta_60m_monthly = theta_Sbeaufort.isel(k=17).mean(dim=['i', 'j']).resample(time='1MS').mean().compute()

# %%
# plot time series of theta at surface, 20, and 60 m
fig, ax1 = plt.subplots(1,1,figsize=[10,3])

theta_00m_monthly.plot(ax=ax1,label='Surface')
theta_20m_monthly.plot(ax=ax1,label='20 m')
theta_60m_monthly.plot(ax=ax1,label='60 m')

plt.title("Southern Beaufort")
plt.grid(linestyle='dashed',linewidth=0.5)
plt.legend(ncol=3);
